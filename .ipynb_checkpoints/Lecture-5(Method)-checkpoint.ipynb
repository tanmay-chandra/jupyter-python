# %%
email=input("enter gmail:")

first_name=email.split("@")[0].split(".")[0]
last_name=email.split("@")[0].split(".")[1]
print(f"Hi {first_name} {last_name} welcome.")
# Out:
# enter gmail: ram.kumar@gmail.com
# Hi ram kumar welcome.

# %%
"name@city@hi@hi@this@no2".split("@",maxsplit=2)
# Out:
# ['name', 'city', 'hi@hi@this@no2']

# %%
"name@city@hi@hi@this@no2".rsplit("@",maxsplit=3)
# Out:
# ['name@city@hi', 'hi', 'this', 'no2']

# %%
"name@city@hi@hi@this@no2".rsplit("@")
# Out:
# ['name', 'city', 'hi', 'hi', 'this', 'no2']

# %%
name="RAMan"
print(name.lower())
# Out:
# raman

# %%
name="RAMan"
print(name.upper())
# Out:
# RAMAN

# %%
name="raman is a boy"
print(name.title())
# Out:
# Raman Is A Boy

# %%
name="RAMan is a boy"
print(name.capitalize())
# Out:
# Raman is a boy

# %%
name="__RAMan"
print(name.strip("__"))
# Out:
# RAMan

# %%
name="__RAMan"
print(name.lstrip("__"))
# Out:
# RAMan

# %%
name="RAMan__"
print(name.rstrip("__"))
# Out:
# RAMan

# %%
name="RAMAN__"
print(name.replace("__","@@"))
# Out:
# RAMAN@@

# %%
name="RAMAN__KUMar"
print(name.split("__"))
# Out:
# ['RAMAN', 'KUMar']

# %%
name=["raman","kumar"]
print("-".join(name))
# Out:
# raman-kumar

# %%
name="hello world"
print(name.find("o"))
# Out:
# 4

# %%
name="hello world"
print(name.index("l"))
# Out:
# 2

# %%
name="hello world"
print(name.count("l"))
# Out:
# 3

# %%
name="hello world"
print(name.startswith("h"))
# Out:
# True

# %%
name="hello world"
print(name.endswith("d"))
# Out:
# True

# %% [markdown]
# # space is not a alphabet

# %%
name="hello world"
print(name.isalpha())
# Out:
# False

# %%
name="helloworld"
print(name.isalpha())
# Out:
# True

# %%
name="12345"
print(name.isdigit())
# Out:
# True

# %%
name="1e2ff3"
print(name.isalnum())
# Out:
# True

# %%
name=" "
print(name.isspace())
# Out:
# True

# %%
name=" "
print(name.format())

# %%
sen="I {name} is learning {language}"
print(sen.format(name="Riya",language="python"))
# Out:
# I Riya is learning python

# %%
my_string = "343434"
print(my_string.isalnum())
# Out:
# True
