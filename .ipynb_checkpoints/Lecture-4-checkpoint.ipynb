# %%
name=input("enter your full name")
city=input("enter your city")
print(f"Hi {name} your city is {city}")
# Out:
# enter your full name tanmay
# enter your city delhi
# Hi tanmay your city is delhi

# %%
name="sAchiN"

# %%
new_name=name.capitalize()

# %%
print(name)
# Out:
# sAchiN

# %% [markdown]
# # press tab after fullstop
# # press shift+tab for description

# %%
print(new_name)
# Out:
# Sachin

# %%
name=input("enter your full name")
city=input("enter your city")
print(f"Hi {name.capitalize()} your city is {city.capitalize()}")
# Out:
# enter your full name taNMAY
# enter your city DELhi
# Hi Tanmay your city is Delhi

# %%
name=name.upper()
print(name)
# Out:
# TANMAY

# %%
# First define the name variable with a string value
name = "example"  # Define name before using it
# Then use endswith() with a suffix argument to check
name = name.endswith(".txt")  # Provide an argument to endswith() method
print(name)
# Out:
# False

# %%
sen="this is noida city noida noida"

# %%
sen.replace("noida","delhi")
# Out:
# 'this is delhi city delhi delhi'

# %%
sen.replace("noida","delhi",count=-1)
# Out:
# 'this is delhi city delhi delhi'

# %%
sen.replace("d","Z",count=2)
# Out:
# 'this is noiZa city noiZa noida'

# %%
number="299999"
number.isnumeric()
# Out:
# True

# %%
number="kkkkk999"
number.isalnum()
# Out:
# True

# %%
number="abc"
number.isalpha()
# Out:
# True

# %%
password=input("enter your password:")
if not password.isalnum():
    print("only characters and numbers allowed")
# Out:
# enter your password: tanmay=-==
# only characters and numbers allowed

# %%
# \\b removes char

# %%
print("this is \tpython")

print("this is \npython")

print("this is\b\b python")

print('It\'s \'python\'')

print("In python \\n is used for new line char")

print(r"this is \n new line \t char this is \b")
# Out:
# this is 	python
# this is
# python
# this  python
# It's 'python'
# In python \n is used for new line char
# this is \n new line \t char this is \b

# %%
print("this is\b\bpython")
# Out:
# this python
