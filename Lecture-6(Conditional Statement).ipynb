# %%
number=int(input("enter your number:"))
if number<0:
    print("number is negative")
    print("done")
else:
    print("number is positive")
# Out:
# enter your number: -123
# number is negative
# done

# %%
marks=int(input("enter your marks:"))

if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Fail")
# Out:
# enter your marks: 58
# Grade C

# %%
pin=1234
mobile=1111
balance=1000

# %%
entered_pin=int(input("enter your pin:"))
if entered_pin==pin:
    print("correct pin")
    entered_mob=int(input("enter your mobile number:"))
    if entered_mob==mobile:
        print("correct mobile go for withdraw")
        amt=int(input("enter amount to withdraw:"))
        if amt<=balance:
            print("remaining balance is : ",balance-amt)
            balance=balance-amt
            print("transaction succesful")
        else:
            print("low balance")
    else:
        print("incorrect mobile no")
else:
    print("incorrect pin")
# Out:
# enter your pin: 1234
# correct pin
# enter your mobile number: 1111
# correct mobile go for withdraw
# enter amount to withdraw: 500
# remaining balance is :  0
# transaction succesful

# %%
if 0:
    print("hi")
else:
    print("bye")
# Out:
# bye

# %%
if 1:
    print("hi")
else:
    print("bye")
# Out:
# hi

# %%
if []:
    print("hi")
else:
    print("bye")
# Out:
# bye

# %%
product_cart={"pen":100,"book":200}
if []
