# %%
age=int(input("enter age:"))
if age>=18:
    print("you can vote")
else:
    print("you cannot vote")
# Out:
# enter age: 3
# you cannot vote

# %%
num=int(input("enter number:"))
if num>=0:
    print("num is positive")
else:
    print("num is negative")
# Out:
# enter number: 0
# num is positive

# %%
num=int(input("enter number:"))
if num%2==0:
    print("num is even")
else:
    print("num is odd")
# Out:
# enter number: 23
# num is odd

# %%
marks=int(input("enter marks:"))
if marks>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# enter marks: 33
# Fail

# %%
password="python123"
enter_pass=input("enter password:")
if enter_pass==password:
    print("Login succesful")
else:
    print("Wrong password")
# Out:
# enter password: python123
# Login succesful

# %%
temp=int(input("enter temperature:"))
if temp>30:
    print("hot day")
else:
    print("normal day")
# Out:
# enter temperature: 22
# normal day

# %%
num1=int(input("enter first num:"))
num2=int(input("enter second num:"))
if num1>num2:
    print("greatest between two num:",num1)
else:
    print("greatest between two num:",num2)
# Out:
# enter first num: 33
# enter second num: 22
# greatest between two num: 33

# %%
num=int(input("enter num:"))
if num%5==0:
    print("num is divisible")
else:
    print("num is not divisible")
# Out:
# enter num: 45
# num is divisible

# %%
username="admin"
user_id=input("enter username:")
if username==user_id:
    print("welcome admin")
else:
    print("welcome user")
# Out:
# enter username: tanmay
# welcome user

# %%
exam_score=int(input("enter score:"))
if exam_score>=90:
    print("Excellent")
else:
    print("Keep practising")
# Out:
# enter score: 99
# Excellent

# %%
num=int(input("enter num:"))
if num==0:
    print("num is zero")
else:
    print("num is not zero")
# Out:
# enter num: 55
# num is not zero

# %%
age=int(input("enter age:"))
if age<13:
    print("child")
else:
    print("teenager or adult")
# Out:
# enter age: 12
# child

# %%
str=input("enter character:")
if str=='a':
    print("a")
else:
    print("not a")
# Out:
# enter character: a
# a

# %%
price=int(input("enter price:"))
if price>1000:
    
    print("discount available")
else:
    print("no discount")
# Out:
# enter price: 333
# no discount
